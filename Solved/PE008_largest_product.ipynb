# %%
def multiplica(lista):
    resultado = 1
    for n in lista:
        resultado *= n

    return resultado

# %%
num00 = str(73167176531330624919225119674426574742355349194934)
num01 = str(96983520312774506326239578318016984801869478851843)
num02 = str(85861560789112949495459501737958331952853208805511)
num03 = str(12540698747158523863050715693290963295227443043557)
num04 = str(66896648950445244523161731856403098711121722383113)
num05 = str(62229893423380308135336276614282806444486645238749)
num06 = str(30358907296290491560440772390713810515859307960866)
num07 = str(70172427121883998797908792274921901699720888093776)
num08 = str(65727333001053367881220235421809751254540594752243)
num09 = str(52584907711670556013604839586446706324415722155397)
num10 = str(53697817977846174064955149290862569321978468622482)
num11 = str(83972241375657056057490261407972968652414535100474)
num12 = str(82166370484403199890008895243450658541227588666881)
num13 = str(16427171479924442928230863465674813919123162824586)
num14 = str(17866458359124566529476545682848912883142607690042)
num15 = str(2421902267105562632111110937054421750694165896040)
num16 = str(807198403850962455444362981230987879927244284909188)
num17 = str(8458015616609791913387549920052406368991256071760)
num18 = str(605886116467109405077541002256983155200055935729725)
num19 = str(71636269561882670428252483600823257530420752963450)

# %%
listao = [num00, num01, num02, num03, num04, num05, num06, num07, num08, num09,
          num10, num11, num12, num13, num14, num15, num16, num17, num18, num19]

# %%
digitos = []
for l in listao:
    for d in l:
        digitos.append(int(d))

len(digitos)
# Out:
# 1000

# %%
num_digitos = 13
max = len(digitos)-num_digitos
grupo = []

# Primeira leva
for i in range(num_digitos):
    grupo.append(digitos[i])

resultado = multiplica(grupo)

# calcula proximos e compara
for i in range (num_digitos, len(digitos)):
    grupo.pop(0)
    grupo.append(digitos[i])

    parcial = multiplica(grupo)

    if parcial>resultado:
        resultado = parcial

print(resultado)
# Out:
# 23514624000

# %%
def multiply(list_):
    result = 1
    for n in list_:
        result *= n

    return result

# %%
number = ...

# %%
number = list(str(number))
number = [int(i) for i in number]
number

# %%
num_digits = 13

result = 0

groups = []

for i in range(len(number)-num_digits+1):
    step = multiply(number[i:i+num_digits])
    groups.append((number[i:i+num_digits], step, i))

    if step > result:
        result = step

print(result)
# Out:
# 23514624000

# %%
groups
# Out:
# [([7, 3, 1, 6], 126, 0),
#  ([3, 1, 6, 7], 126, 1),
#  ([1, 6, 7, 1], 42, 2),
#  ([6, 7, 1, 7], 294, 3),
#  ([7, 1, 7, 6], 294, 4),
#  ([1, 7, 6, 5], 210, 5),
#  ([7, 6, 5, 3], 630, 6),
#  ([6, 5, 3, 1], 90, 7),
#  ([5, 3, 1, 3], 45, 8),
#  ([3, 1, 3, 3], 27, 9),
#  ([1, 3, 3, 0], 0, 10),
#  ([3, 3, 0, 6], 0, 11),
#  ([3, 0, 6, 2], 0, 12),
#  ([0, 6, 2, 4], 0, 13),
#  ([6, 2, 4, 9], 432, 14),
#  ([2, 4, 9, 1], 72, 15),
#  ([4, 9, 1, 9], 324, 16),
#  ([9, 1, 9, 2], 162, 17),
#  ([1, 9, 2, 2], 36, 18),
#  ([9, 2, 2, 5], 180, 19),
#  ([2, 2, 5, 1], 20, 20),
#  ([2, 5, 1, 1], 10, 21),
#  ([5, 1, 1, 9], 45, 22),
#  ([1, 1, 9, 6], 54, 23),
#  ([1, 9, 6, 7], 378, 24),
#  ([9, 6, 7, 4], 1512, 25),
#  ([6, 7, 4, 4], 672, 26),
#  ([7, 4, 4, 2], 224, 27),
#  ([4, 4, 2, 6], 192, 28),
#  ([4, 2, 6, 5], 240, 29),
#  ([2, 6, 5, 7], 420, 30),
#  ([6, 5, 7, 4], 840, 31),
#  ([5, 7, 4, 7], 980, 32),
#  ([7, 4, 7, 4], 784, 33),
#  ([4, 7, 4, 2], 224, 34),
#  ([7, 4, 2, 3], 168, 35),
# ...
