# %% [markdown]
# The primes $3$, $7$, $109$, and $673$, are quite remarkable. By taking any two primes and concatenating them in any order the result will always be prime. For example, taking $7$ and $109$, both $7109$ and $1097$ are prime. The sum of these four primes, $792$, represents the lowest sum for a set of four primes with this property.
#
# Find the lowest sum for a set of five primes for which any two primes concatenate to produce another prime.

# %%
from itertools import combinations, product, takewhile
from math import sqrt
from time import perf_counter

# %%
def primes_gen():
    primos = set()
    primos.add(2)
    yield 2

    valor = 3
    while True:
        validador = True
        for p in primos:
            if valor%p == 0:
                validador = False
                break

        if validador:
            primos.add(valor)
            yield valor

        valor += 2

# %%
def test_prime(num: int) -> bool:
    global primes, all_primes
    max_test = int(sqrt(num))
    while max(all_primes) < max_test:
        all_primes.append(next(primes))
    
    for n in takewhile(lambda x: x <= max_test, all_primes):
        if num % n == 0:
            return False

    return True

# %%
all_primes = []
primes = primes_gen()
while True:
    current = next(primes)
    all_primes.append(current)
    if current > 10000:
        break

primes_minus_2 = all_primes.copy()
primes_minus_2.remove(2)

# %%
print(f'{len(all_primes)=}; {max(all_primes)}')
# Out:
# len(all_primes)=3399; 31583

# %%
bad_pairs = set()
set_primes = combinations(all_primes, 2)
for p1, p2 in set_primes:
    conc1 = int(str(p1) + str(p2))
    conc2 = int(str(p2) + str(p1))
    if test_prime(conc1) and test_prime(conc2):
        # print(f'{p1}, {p2} is not bad')
        continue
    bad_pairs.add((p1, p2))
    bad_pairs.add((p2, p1))
    
len(bad_pairs)
# Out:
# 1475286

# %%
max(all_primes)
# Out:
# 5479

# %%
set_primes = combinations(primes_minus_2, 4)
count = 0
set_sum = 0
start = perf_counter()
pos_results = []
for conj in set_primes:
    count += 1
    # if count % 1000000 == 0:
    #     print(f'{count=}; {conj=}; time elapsed: {perf_counter()-start}s')
    list_primes = list(conj)
    if 2 in conj: # 2 cannot be part of the set
        continue
    if sum(conj)>20000: # maximum sum allowed 
        continue
    if conj == (3, 7, 109, 673):
        continue
    list_primes.sort()
    good_set = True

    for p1, p2 in product(list_primes, repeat=2):
        if p1 == p2:
            continue
        
        if ((p1, p2) in bad_pairs) or ((p2, p1) in bad_pairs):
            good_set = False
            break

        # conc1 = int(str(p1)+str(p2))
        # conc2 = int(str(p2)+str(p1))

        # if not test_prime(conc1) or not test_prime(conc2):
        #     good_set = False
        #     bad_pairs.append((p1, p2))
        #     break

    if good_set:
        # set_sum = sum(conj)
        # break
        pos_results.append(conj)

# if good_set:
#     print(f'Resultado positivo. O conjunto {conj} tem soma {set_sum}')
# else:
#     print(f'Resultado negativo. Foram testados {count} conjuntos e o último foi {conj}.')
print(pos_results)
print(f'Tempo total: {perf_counter()-start}s')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 13
#      11 if 2 in conj: # 2 cannot be part of the set
#      12     continue
# ---> 13 if sum(conj)>20000: # maximum sum allowed
#      14     continue
#      15 if conj == (3, 7, 109, 673):
#
# KeyboardInterrupt:

# %%
# print(pos_results)
len(pos_results)
# Out:
# 10425

# %%
primes_minus_2 = all_primes.copy()
primes_minus_2.remove(2)

# %%
set_primes = combinations(primes_minus_2, 4)
count = 0
set_sum = 0
start = perf_counter()
pos_results = []
for conj in set_primes:
    count += 1
    # if count % 1000000 == 0:
    #     print(f'{count=}; {conj=}; time elapsed: {perf_counter()-start}s')
    list_primes = list(conj)
    if 2 in conj: # 2 cannot be part of the set
        continue
    if sum(conj)>20000: # maximum sum allowed 
        continue
    if conj == (3, 7, 109, 673):
        continue
    list_primes.sort()
    good_set = True

    for p1, p2 in product(list_primes, repeat=2):
        if p1 == p2:
            continue
        
        if ((p1, p2) in bad_pairs) or ((p2, p1) in bad_pairs):
            good_set = False
            break

        # conc1 = int(str(p1)+str(p2))
        # conc2 = int(str(p2)+str(p1))

        # if not test_prime(conc1) or not test_prime(conc2):
        #     good_set = False
        #     bad_pairs.append((p1, p2))
        #     break

    if good_set:
        print(f'Testando o conjunto {conj}')
        for p5 in primes_minus_2:
            if p5 <= max(conj):
                continue
            list_primes = list(conj)
            list_primes.append(p5)
            conj = tuple(list_primes)
            
            for p1, p2 in product(list_primes, repeat=2):
                if p1 == p2:
                    continue
                
                if ((p1, p2) in bad_pairs) or ((p2, p1) in bad_pairs):
                    good_set = False
                    break

                conc1 = int(str(p1)+str(p2))
                conc2 = int(str(p2)+str(p1))

                if not test_prime(conc1) or not test_prime(conc2):
                    good_set = False
                    bad_pairs.add((p1, p2))
                    break

            if good_set:
                # conj = (p1, p2, p3, p4, p5)
                set_sum = sum(conj)
                break



if good_set:
    print(f'Resultado positivo. O conjunto {conj} tem soma {set_sum}')
else:
    print(f'Resultado negativo. Foram testados {count} conjuntos e o último foi {conj}.')
# print(pos_results)
print(f'Tempo total: {perf_counter()-start}s')
# Out:
# Testando o conjunto (3, 7, 229, 10459)
# Testando o conjunto (3, 7, 229, 10627)
# Testando o conjunto (3, 7, 229, 14851)
# Testando o conjunto (3, 7, 229, 15313)
# Testando o conjunto (3, 7, 229, 19183)
# Testando o conjunto (3, 7, 229, 19237)
# Testando o conjunto (3, 7, 541, 4159)
# Testando o conjunto (3, 7, 541, 10459)
# Testando o conjunto (3, 7, 541, 10627)
# Testando o conjunto (3, 7, 541, 14851)
# Testando o conjunto (3, 7, 541, 15313)
# Testando o conjunto (3, 7, 541, 19183)
# Testando o conjunto (3, 7, 541, 19237)
# Testando o conjunto (3, 7, 673, 10459)
# Testando o conjunto (3, 7, 673, 10627)
# Testando o conjunto (3, 7, 673, 14851)
# Testando o conjunto (3, 7, 673, 15313)
# Testando o conjunto (3, 7, 673, 19183)
# Testando o conjunto (3, 7, 673, 19237)
# Testando o conjunto (3, 7, 823, 10459)
# Testando o conjunto (3, 7, 823, 10627)
# Testando o conjunto (3, 7, 823, 14851)
# Testando o conjunto (3, 7, 823, 15313)
# Testando o conjunto (3, 7, 1237, 10459)
# Testando o conjunto (3, 7, 1237, 10627)
# Testando o conjunto (3, 7, 1237, 14851)
# Testando o conjunto (3, 7, 1237, 15313)
# Testando o conjunto (3, 7, 2503, 10459)
# Testando o conjunto (3, 7, 2503, 10627)
# Testando o conjunto (3, 7, 2503, 14851)
# Testando o conjunto (3, 7, 2503, 15313)
# Testando o conjunto (3, 7, 2707, 10459)
# Testando o conjunto (3, 7, 2707, 10627)
# Testando o conjunto (3, 7, 2707, 14851)
# Testando o conjunto (3, 7, 2707, 15313)
# Testando o conjunto (3, 7, 4159, 10459)
# Testando o conjunto (3, 7, 4159, 10627)
# Testando o conjunto (3, 7, 4159, 14851)
# Testando o conjunto (3, 7, 4159, 15313)
# Testando o conjunto (3, 7, 4729, 10459)
# Testando o conjunto (3, 7, 4729, 10627)
# Testando o conjunto (3, 7, 4729, 14851)
# Testando o conjunto (3, 7, 5521, 10459)
# Testando o conjunto (3, 7, 5521, 10627)
# Testando o conjunto (3, 11, 701, 8747)
# Testando o conjunto (3, 11, 701, 10091)
# Testando o conjunto (3, 11, 701, 10111)
# Testando o conjunto (3, 11, 701, 10169)
# Testando o conjunto (3, 11, 701, 10223)
# Testando o conjunto (3, 11, 701, 10243)
# Testando o conjunto (3, 11, 701, 10333)
# Testando o conjunto (3, 11, 701, 10357)
# Testando o conjunto (3, 11, 701, 10459)
# Testando o conjunto (3, 11, 701, 10567)
# Testando o conjunto (3, 11, 701, 10627)
# Testando o conjunto (3, 11, 701, 10771)
# Testando o conjunto (3, 11, 701, 10889)
# Testando o conjunto (3, 11, 701, 10987)
# Testando o conjunto (3, 11, 701, 11027)
# Testando o conjunto (3, 11, 701, 11173)
# Testando o conjunto (3, 11, 701, 11177)
# Testando o conjunto (3, 11, 701, 11197)
# Testando o conjunto (3, 11, 701, 11393)
# Testando o conjunto (3, 11, 701, 11447)
# Testando o conjunto (3, 11, 701, 11551)
# Testando o conjunto (3, 11, 701, 11821)
# Testando o conjunto (3, 11, 701, 11827)
# Testando o conjunto (3, 11, 701, 11867)
# Testando o conjunto (3, 11, 701, 11897)
# Testando o conjunto (3, 11, 701, 11981)
# Testando o conjunto (3, 11, 701, 12071)
# Testando o conjunto (3, 11, 701, 12101)
# Testando o conjunto (3, 11, 701, 12203)
# Testando o conjunto (3, 11, 701, 12253)
# Testando o conjunto (3, 11, 701, 12269)
# Testando o conjunto (3, 11, 701, 12343)
# Testando o conjunto (3, 11, 701, 12413)
# Testando o conjunto (3, 11, 701, 12451)
# Testando o conjunto (3, 11, 701, 12601)
# Testando o conjunto (3, 11, 701, 12703)
# Testando o conjunto (3, 11, 701, 12841)
# Testando o conjunto (3, 11, 701, 12899)
# Testando o conjunto (3, 11, 701, 12979)
# Testando o conjunto (3, 11, 701, 13381)
# Testando o conjunto (3, 11, 701, 13399)
# Testando o conjunto (3, 11, 701, 13553)
# Testando o conjunto (3, 11, 701, 13613)
# Testando o conjunto (3, 11, 701, 13619)
# Testando o conjunto (3, 11, 701, 13669)
# Testando o conjunto (3, 11, 701, 13763)
# Testando o conjunto (3, 11, 701, 13879)
# Testando o conjunto (3, 11, 701, 13931)
# Testando o conjunto (3, 11, 701, 13933)
# Testando o conjunto (3, 11, 701, 14107)
# Testando o conjunto (3, 11, 701, 14243)
# Testando o conjunto (3, 11, 701, 14401)
# Testando o conjunto (3, 11, 701, 14407)
# Testando o conjunto (3, 11, 701, 14543)
# Testando o conjunto (3, 11, 701, 14627)
# Testando o conjunto (3, 11, 701, 14779)
# Testando o conjunto (3, 11, 701, 14851)
# Testando o conjunto (3, 11, 701, 14879)
# Testando o conjunto (3, 11, 701, 15083)
# Testando o conjunto (3, 11, 701, 15313)
# Testando o conjunto (3, 11, 701, 15373)
# Testando o conjunto (3, 11, 701, 15461)
# Testando o conjunto (3, 11, 701, 15493)
# Testando o conjunto (3, 11, 701, 15559)
# Testando o conjunto (3, 11, 701, 15569)
# Testando o conjunto (3, 11, 701, 15739)
# Testando o conjunto (3, 11, 701, 15907)
# Testando o conjunto (3, 11, 701, 16339)
# Testando o conjunto (3, 11, 701, 16363)
# Testando o conjunto (3, 11, 701, 16567)
# Testando o conjunto (3, 11, 701, 16661)
# Testando o conjunto (3, 11, 701, 16703)
# Testando o conjunto (3, 11, 701, 16759)
# Testando o conjunto (3, 11, 701, 16937)
# Testando o conjunto (3, 11, 701, 17021)
# Testando o conjunto (3, 11, 701, 17029)
# Testando o conjunto (3, 11, 701, 17047)
# Testando o conjunto (3, 11, 701, 17077)
# Testando o conjunto (3, 11, 701, 17123)
# Testando o conjunto (3, 11, 701, 17209)
# Testando o conjunto (3, 11, 701, 17257)
# Testando o conjunto (3, 11, 701, 17327)
# Testando o conjunto (3, 11, 701, 17489)
# Testando o conjunto (3, 11, 701, 17539)
# Testando o conjunto (3, 11, 701, 17599)
# Testando o conjunto (3, 11, 701, 17789)
# Testando o conjunto (3, 11, 701, 17839)
# Testando o conjunto (3, 11, 701, 17903)
# Testando o conjunto (3, 11, 701, 17921)
# Testando o conjunto (3, 11, 701, 17923)
# Testando o conjunto (3, 11, 701, 17957)
# Testando o conjunto (3, 11, 701, 17959)
# Testando o conjunto (3, 11, 701, 18077)
# Testando o conjunto (3, 11, 701, 18127)
# Testando o conjunto (3, 11, 701, 18181)
# Testando o conjunto (3, 11, 701, 18191)
# Testando o conjunto (3, 11, 701, 18233)
# Testando o conjunto (3, 11, 701, 18289)
# Testando o conjunto (3, 11, 701, 18523)
# Testando o conjunto (3, 11, 701, 18679)
# Testando o conjunto (3, 11, 701, 18713)
# Testando o conjunto (3, 11, 701, 18743)
# Testando o conjunto (3, 11, 701, 19031)
# Testando o conjunto (3, 11, 701, 19183)
# Testando o conjunto (3, 11, 701, 19211)
# Testando o conjunto (3, 11, 701, 19237)
# Testando o conjunto (3, 11, 2069, 2297)
# Testando o conjunto (3, 11, 2069, 8219)
# Testando o conjunto (3, 11, 2069, 8747)
# Testando o conjunto (3, 11, 2069, 10091)
# Testando o conjunto (3, 11, 2069, 10111)
# Testando o conjunto (3, 11, 2069, 10169)
# Testando o conjunto (3, 11, 2069, 10243)
# Testando o conjunto (3, 11, 2069, 10333)
# Testando o conjunto (3, 11, 2069, 10357)
# Testando o conjunto (3, 11, 2069, 10459)
# Testando o conjunto (3, 11, 2069, 10567)
# Testando o conjunto (3, 11, 2069, 10627)
# Testando o conjunto (3, 11, 2069, 10771)
# Testando o conjunto (3, 11, 2069, 10889)
# Testando o conjunto (3, 11, 2069, 10987)
# Testando o conjunto (3, 11, 2069, 11027)
# Testando o conjunto (3, 11, 2069, 11197)
# Testando o conjunto (3, 11, 2069, 11393)
# Testando o conjunto (3, 11, 2069, 11447)
# Testando o conjunto (3, 11, 2069, 11551)
# Testando o conjunto (3, 11, 2069, 11827)
# Testando o conjunto (3, 11, 2069, 11867)
# Testando o conjunto (3, 11, 2069, 11897)
# Testando o conjunto (3, 11, 2069, 11981)
# Testando o conjunto (3, 11, 2069, 12071)
# Testando o conjunto (3, 11, 2069, 12101)
# Testando o conjunto (3, 11, 2069, 12203)
# Testando o conjunto (3, 11, 2069, 12253)
# Testando o conjunto (3, 11, 2069, 12269)
# Testando o conjunto (3, 11, 2069, 12343)
# Testando o conjunto (3, 11, 2069, 12413)
# Testando o conjunto (3, 11, 2069, 12451)
# Testando o conjunto (3, 11, 2069, 12601)
# Testando o conjunto (3, 11, 2069, 12703)
# Testando o conjunto (3, 11, 2069, 12841)
# Testando o conjunto (3, 11, 2069, 12899)
# Testando o conjunto (3, 11, 2069, 12979)
# Testando o conjunto (3, 11, 2069, 13381)
# Testando o conjunto (3, 11, 2069, 13399)
# Testando o conjunto (3, 11, 2069, 13553)
# Testando o conjunto (3, 11, 2069, 13619)
# Testando o conjunto (3, 11, 2069, 13669)
# Testando o conjunto (3, 11, 2069, 13763)
# Testando o conjunto (3, 11, 2069, 13879)
# Testando o conjunto (3, 11, 2069, 13933)
# Testando o conjunto (3, 11, 2069, 14107)
# Testando o conjunto (3, 11, 2069, 14243)
# Testando o conjunto (3, 11, 2069, 14407)
# Testando o conjunto (3, 11, 2069, 14543)
# Testando o conjunto (3, 11, 2069, 14627)
# Testando o conjunto (3, 11, 2069, 14779)
# Testando o conjunto (3, 11, 2069, 14851)
# Testando o conjunto (3, 11, 2069, 14879)
# Testando o conjunto (3, 11, 2069, 15083)
# Testando o conjunto (3, 11, 2069, 15313)
# Testando o conjunto (3, 11, 2069, 15373)
# Testando o conjunto (3, 11, 2069, 15461)
# Testando o conjunto (3, 11, 2069, 15493)
# Testando o conjunto (3, 11, 2069, 15569)
# Testando o conjunto (3, 11, 2069, 15739)
# Testando o conjunto (3, 11, 2069, 15907)
# Testando o conjunto (3, 11, 2069, 16339)
# Testando o conjunto (3, 11, 2069, 16363)
# Testando o conjunto (3, 11, 2069, 16567)
# Testando o conjunto (3, 11, 2069, 16661)
# Testando o conjunto (3, 11, 2069, 16703)
# Testando o conjunto (3, 11, 2069, 16759)
# Testando o conjunto (3, 11, 2069, 16937)
# Testando o conjunto (3, 11, 2069, 17021)
# Testando o conjunto (3, 11, 2069, 17029)
# Testando o conjunto (3, 11, 2069, 17047)
# Testando o conjunto (3, 11, 2069, 17077)
# Testando o conjunto (3, 11, 2069, 17123)
# Testando o conjunto (3, 11, 2069, 17209)
# Testando o conjunto (3, 11, 2069, 17257)
# Testando o conjunto (3, 11, 2069, 17327)
# Testando o conjunto (3, 11, 2069, 17489)
# Testando o conjunto (3, 11, 2069, 17539)
# Testando o conjunto (3, 11, 2069, 17599)
# Testando o conjunto (3, 11, 2069, 17789)
# Testando o conjunto (3, 11, 2069, 17839)
# Testando o conjunto (3, 11, 2069, 17903)
# Testando o conjunto (3, 11, 2213, 10091)
# Testando o conjunto (3, 11, 2213, 10111)
# Testando o conjunto (3, 11, 2213, 10169)
# Testando o conjunto (3, 11, 2213, 10243)
# Testando o conjunto (3, 11, 2213, 10333)
# Testando o conjunto (3, 11, 2213, 10357)
# Testando o conjunto (3, 11, 2213, 10459)
# Testando o conjunto (3, 11, 2213, 10567)
# Testando o conjunto (3, 11, 2213, 10627)
# Testando o conjunto (3, 11, 2213, 10771)
# Testando o conjunto (3, 11, 2213, 10889)
# Testando o conjunto (3, 11, 2213, 10987)
# Testando o conjunto (3, 11, 2213, 11027)
# Testando o conjunto (3, 11, 2213, 11197)
# Testando o conjunto (3, 11, 2213, 11393)
# Testando o conjunto (3, 11, 2213, 11447)
# Testando o conjunto (3, 11, 2213, 11551)
# Testando o conjunto (3, 11, 2213, 11827)
# Testando o conjunto (3, 11, 2213, 11867)
# Testando o conjunto (3, 11, 2213, 11897)
# Testando o conjunto (3, 11, 2213, 11981)
# Testando o conjunto (3, 11, 2213, 12071)
# Testando o conjunto (3, 11, 2213, 12101)
# Testando o conjunto (3, 11, 2213, 12203)
# Testando o conjunto (3, 11, 2213, 12253)
# Testando o conjunto (3, 11, 2213, 12269)
# Testando o conjunto (3, 11, 2213, 12343)
# Testando o conjunto (3, 11, 2213, 12413)
# Testando o conjunto (3, 11, 2213, 12451)
# Testando o conjunto (3, 11, 2213, 12601)
# Testando o conjunto (3, 11, 2213, 12703)
# Testando o conjunto (3, 11, 2213, 12841)
# Testando o conjunto (3, 11, 2213, 12899)
# Testando o conjunto (3, 11, 2213, 12979)
# Testando o conjunto (3, 11, 2213, 13381)
# Testando o conjunto (3, 11, 2213, 13399)
# Testando o conjunto (3, 11, 2213, 13553)
# Testando o conjunto (3, 11, 2213, 13619)
# Testando o conjunto (3, 11, 2213, 13669)
# Testando o conjunto (3, 11, 2213, 13763)
# Testando o conjunto (3, 11, 2213, 13879)
# Testando o conjunto (3, 11, 2213, 13933)
# Testando o conjunto (3, 11, 2213, 14107)
# Testando o conjunto (3, 11, 2213, 14243)
# Testando o conjunto (3, 11, 2213, 14407)
# Testando o conjunto (3, 11, 2213, 14543)
# Testando o conjunto (3, 11, 2213, 14627)
# Testando o conjunto (3, 11, 2213, 14779)
# Testando o conjunto (3, 11, 2213, 14851)
# Testando o conjunto (3, 11, 2213, 14879)
# Testando o conjunto (3, 11, 2213, 15083)
# Testando o conjunto (3, 11, 2213, 15313)
# Testando o conjunto (3, 11, 2213, 15373)
# Testando o conjunto (3, 11, 2213, 15461)
# Testando o conjunto (3, 11, 2213, 15493)
# Testando o conjunto (3, 11, 2213, 15569)
# Testando o conjunto (3, 11, 2213, 15739)
# Testando o conjunto (3, 11, 2213, 15907)
# Testando o conjunto (3, 11, 2213, 16339)
# Testando o conjunto (3, 11, 2213, 16363)
# Testando o conjunto (3, 11, 2213, 16567)
# Testando o conjunto (3, 11, 2213, 16661)
# Testando o conjunto (3, 11, 2213, 16703)
# Testando o conjunto (3, 11, 2213, 16759)
# Testando o conjunto (3, 11, 2213, 16937)
# Testando o conjunto (3, 11, 2213, 17021)
# Testando o conjunto (3, 11, 2213, 17029)
# Testando o conjunto (3, 11, 2213, 17047)
# Testando o conjunto (3, 11, 2213, 17077)
# Testando o conjunto (3, 11, 2213, 17123)
# Testando o conjunto (3, 11, 2213, 17209)
# Testando o conjunto (3, 11, 2213, 17257)
# Testando o conjunto (3, 11, 2213, 17327)
# Testando o conjunto (3, 11, 2213, 17489)
# Testando o conjunto (3, 11, 2213, 17539)
# Testando o conjunto (3, 11, 2213, 17599)
# Testando o conjunto (3, 11, 2297, 10091)
# Testando o conjunto (3, 11, 2297, 10111)
# Testando o conjunto (3, 11, 2297, 10169)
# Testando o conjunto (3, 11, 2297, 10243)
# Testando o conjunto (3, 11, 2297, 10333)
# Testando o conjunto (3, 11, 2297, 10357)
# Testando o conjunto (3, 11, 2297, 10459)
# Testando o conjunto (3, 11, 2297, 10567)
# Testando o conjunto (3, 11, 2297, 10627)
# Testando o conjunto (3, 11, 2297, 10771)
# Testando o conjunto (3, 11, 2297, 10889)
# Testando o conjunto (3, 11, 2297, 10987)
# Testando o conjunto (3, 11, 2297, 11027)
# Testando o conjunto (3, 11, 2297, 11197)
# Testando o conjunto (3, 11, 2297, 11393)
# Testando o conjunto (3, 11, 2297, 11447)
# Testando o conjunto (3, 11, 2297, 11551)
# Testando o conjunto (3, 11, 2297, 11827)
# Testando o conjunto (3, 11, 2297, 11867)
# Testando o conjunto (3, 11, 2297, 11897)
# Testando o conjunto (3, 11, 2297, 11981)
# Testando o conjunto (3, 11, 2297, 12071)
# Testando o conjunto (3, 11, 2297, 12101)
# Testando o conjunto (3, 11, 2297, 12203)
# Testando o conjunto (3, 11, 2297, 12253)
# Testando o conjunto (3, 11, 2297, 12269)
# Testando o conjunto (3, 11, 2297, 12343)
# Testando o conjunto (3, 11, 2297, 12413)
# Testando o conjunto (3, 11, 2297, 12451)
# Testando o conjunto (3, 11, 2297, 12601)
# Testando o conjunto (3, 11, 2297, 12703)
# Testando o conjunto (3, 11, 2297, 12841)
# Testando o conjunto (3, 11, 2297, 12899)
# Testando o conjunto (3, 11, 2297, 12979)
# Testando o conjunto (3, 11, 2297, 13381)
# Testando o conjunto (3, 11, 2297, 13399)
# Testando o conjunto (3, 11, 2297, 13553)
# Testando o conjunto (3, 11, 2297, 13619)
# Testando o conjunto (3, 11, 2297, 13669)
# Testando o conjunto (3, 11, 2297, 13763)
# Testando o conjunto (3, 11, 2297, 13879)
# Testando o conjunto (3, 11, 2297, 13933)
# Testando o conjunto (3, 11, 2297, 14107)
# Testando o conjunto (3, 11, 2297, 14243)
# Testando o conjunto (3, 11, 2297, 14407)
# Testando o conjunto (3, 11, 2297, 14543)
# Testando o conjunto (3, 11, 2297, 14627)
# Testando o conjunto (3, 11, 2297, 14779)
# Testando o conjunto (3, 11, 2297, 14851)
# Testando o conjunto (3, 11, 2297, 14879)
# Testando o conjunto (3, 11, 2297, 15083)
# Testando o conjunto (3, 11, 2297, 15313)
# Testando o conjunto (3, 11, 2297, 15373)
# Testando o conjunto (3, 11, 2297, 15461)
# Testando o conjunto (3, 11, 2297, 15493)
# Testando o conjunto (3, 11, 2297, 15569)
# Testando o conjunto (3, 11, 2297, 15739)
# Testando o conjunto (3, 11, 2297, 15907)
# Testando o conjunto (3, 11, 2297, 16339)
# Testando o conjunto (3, 11, 2297, 16363)
# Testando o conjunto (3, 11, 2297, 16567)
# Testando o conjunto (3, 11, 2297, 16661)
# Testando o conjunto (3, 11, 2297, 16703)
# Testando o conjunto (3, 11, 2297, 16759)
# Testando o conjunto (3, 11, 2297, 16937)
# Testando o conjunto (3, 11, 2297, 17021)
# Testando o conjunto (3, 11, 2297, 17029)
# Testando o conjunto (3, 11, 2297, 17047)
# Testando o conjunto (3, 11, 2297, 17077)
# Testando o conjunto (3, 11, 2297, 17123)
# Testando o conjunto (3, 11, 2297, 17209)
# Testando o conjunto (3, 11, 2297, 17257)
# Testando o conjunto (3, 11, 2297, 17327)
# Testando o conjunto (3, 11, 2297, 17489)
# Testando o conjunto (3, 11, 2297, 17539)
# Testando o conjunto (3, 11, 2297, 17599)
# Testando o conjunto (3, 11, 2843, 10091)
# Testando o conjunto (3, 11, 2843, 10111)
# Testando o conjunto (3, 11, 2843, 10169)
# Testando o conjunto (3, 11, 2843, 10243)
# Testando o conjunto (3, 11, 2843, 10333)
# Testando o conjunto (3, 11, 2843, 10357)
# Testando o conjunto (3, 11, 2843, 10459)
# Testando o conjunto (3, 11, 2843, 10567)
# Testando o conjunto (3, 11, 2843, 10627)
# Testando o conjunto (3, 11, 2843, 10771)
# Testando o conjunto (3, 11, 2843, 10889)
# Testando o conjunto (3, 11, 2843, 10987)
# Testando o conjunto (3, 11, 2843, 11027)
# Testando o conjunto (3, 11, 2843, 11197)
# Testando o conjunto (3, 11, 2843, 11393)
# Testando o conjunto (3, 11, 2843, 11447)
# Testando o conjunto (3, 11, 2843, 11551)
# Testando o conjunto (3, 11, 2843, 11827)
# Testando o conjunto (3, 11, 2843, 11867)
# Testando o conjunto (3, 11, 2843, 11897)
# Testando o conjunto (3, 11, 2843, 11981)
# Testando o conjunto (3, 11, 2843, 12071)
# Testando o conjunto (3, 11, 2843, 12101)
# Testando o conjunto (3, 11, 2843, 12203)
# Testando o conjunto (3, 11, 2843, 12253)
# Testando o conjunto (3, 11, 2843, 12269)
# Testando o conjunto (3, 11, 2843, 12343)
# Testando o conjunto (3, 11, 2843, 12413)
# Testando o conjunto (3, 11, 2843, 12451)
# Testando o conjunto (3, 11, 2843, 12601)
# Testando o conjunto (3, 11, 2843, 12703)
# Testando o conjunto (3, 11, 2843, 12841)
# Testando o conjunto (3, 11, 2843, 12899)
# Testando o conjunto (3, 11, 2843, 12979)
# Testando o conjunto (3, 11, 2843, 13381)
# Testando o conjunto (3, 11, 2843, 13399)
# Testando o conjunto (3, 11, 2843, 13553)
# Testando o conjunto (3, 11, 2843, 13619)
# Testando o conjunto (3, 11, 2843, 13669)
# Testando o conjunto (3, 11, 2843, 13763)
# Testando o conjunto (3, 11, 2843, 13879)
# Testando o conjunto (3, 11, 2843, 13933)
# Testando o conjunto (3, 11, 2843, 14107)
# Testando o conjunto (3, 11, 2843, 14243)
# Testando o conjunto (3, 11, 2843, 14407)
# Testando o conjunto (3, 11, 2843, 14543)
# Testando o conjunto (3, 11, 2843, 14627)
# Testando o conjunto (3, 11, 2843, 14779)
# Testando o conjunto (3, 11, 2843, 14851)
# Testando o conjunto (3, 11, 2843, 14879)
# Testando o conjunto (3, 11, 2843, 15083)
# Testando o conjunto (3, 11, 2843, 15313)
# Testando o conjunto (3, 11, 2843, 15373)
# Testando o conjunto (3, 11, 2843, 15461)
# Testando o conjunto (3, 11, 2843, 15493)
# Testando o conjunto (3, 11, 2843, 15569)
# Testando o conjunto (3, 11, 2843, 15739)
# Testando o conjunto (3, 11, 2843, 15907)
# Testando o conjunto (3, 11, 2843, 16339)
# Testando o conjunto (3, 11, 2843, 16363)
# Testando o conjunto (3, 11, 2843, 16567)
# Testando o conjunto (3, 11, 2843, 16661)
# Testando o conjunto (3, 11, 2843, 16703)
# Testando o conjunto (3, 11, 2843, 16759)
# Testando o conjunto (3, 11, 2843, 16937)
# Testando o conjunto (3, 11, 2843, 17021)
# Testando o conjunto (3, 11, 2843, 17029)
# Testando o conjunto (3, 11, 2843, 17047)
# Testando o conjunto (3, 11, 2843, 17077)
# Testando o conjunto (3, 11, 2843, 17123)
# Testando o conjunto (3, 11, 5099, 10091)
# Testando o conjunto (3, 11, 5099, 10111)
# Testando o conjunto (3, 11, 5099, 10169)
# Testando o conjunto (3, 11, 5099, 10243)
# Testando o conjunto (3, 11, 5099, 10333)
# Testando o conjunto (3, 11, 5099, 10357)
# Testando o conjunto (3, 11, 5099, 10459)
# Testando o conjunto (3, 11, 5099, 10567)
# Testando o conjunto (3, 11, 5099, 10627)
# Testando o conjunto (3, 11, 5099, 10771)
# Testando o conjunto (3, 11, 5099, 10889)
# Testando o conjunto (3, 11, 5099, 10987)
# Testando o conjunto (3, 11, 5099, 11027)
# Testando o conjunto (3, 11, 5099, 11197)
# Testando o conjunto (3, 11, 5099, 11393)
# Testando o conjunto (3, 11, 5099, 11447)
# Testando o conjunto (3, 11, 5099, 11551)
# Testando o conjunto (3, 11, 5099, 11827)
# Testando o conjunto (3, 11, 5099, 11867)
# Testando o conjunto (3, 11, 5099, 11897)
# Testando o conjunto (3, 11, 5099, 11981)
# Testando o conjunto (3, 11, 5099, 12071)
# Testando o conjunto (3, 11, 5099, 12101)
# Testando o conjunto (3, 11, 5099, 12203)
# Testando o conjunto (3, 11, 5099, 12253)
# Testando o conjunto (3, 11, 5099, 12269)
# Testando o conjunto (3, 11, 5099, 12343)
# Testando o conjunto (3, 11, 5099, 12413)
# Testando o conjunto (3, 11, 5099, 12451)
# Testando o conjunto (3, 11, 5099, 12601)
# Testando o conjunto (3, 11, 5099, 12703)
# Testando o conjunto (3, 11, 5099, 12841)
# Testando o conjunto (3, 11, 5099, 12899)
# Testando o conjunto (3, 11, 5099, 12979)
# Testando o conjunto (3, 11, 5099, 13381)
# Testando o conjunto (3, 11, 5099, 13399)
# Testando o conjunto (3, 11, 5099, 13553)
# Testando o conjunto (3, 11, 5099, 13619)
# Testando o conjunto (3, 11, 5099, 13669)
# Testando o conjunto (3, 11, 5099, 13763)
# Testando o conjunto (3, 11, 5099, 13879)
# Testando o conjunto (3, 11, 5099, 13933)
# Testando o conjunto (3, 11, 5099, 14107)
# Testando o conjunto (3, 11, 5099, 14243)
# Testando o conjunto (3, 11, 5099, 14407)
# Testando o conjunto (3, 11, 5099, 14543)
# Testando o conjunto (3, 11, 5099, 14627)
# Testando o conjunto (3, 11, 5099, 14779)
# Testando o conjunto (3, 11, 5099, 14851)
# Testando o conjunto (3, 11, 5099, 14879)
# Testando o conjunto (3, 11, 8219, 10091)
# Testando o conjunto (3, 11, 8219, 10111)
# Testando o conjunto (3, 11, 8219, 10169)
# Testando o conjunto (3, 11, 8219, 10243)
# Testando o conjunto (3, 11, 8219, 10333)
# Testando o conjunto (3, 11, 8219, 10357)
# Testando o conjunto (3, 11, 8219, 10459)
# Testando o conjunto (3, 11, 8219, 10567)
# Testando o conjunto (3, 11, 8219, 10627)
# Testando o conjunto (3, 11, 8219, 10771)
# Testando o conjunto (3, 11, 8219, 10889)
# Testando o conjunto (3, 11, 8219, 10987)
# Testando o conjunto (3, 11, 8219, 11027)
# Testando o conjunto (3, 11, 8219, 11197)
# Testando o conjunto (3, 11, 8219, 11393)
# Testando o conjunto (3, 11, 8219, 11447)
# Testando o conjunto (3, 11, 8219, 11551)
# Testando o conjunto (3, 11, 8747, 10091)
# Testando o conjunto (3, 11, 8747, 10111)
# Testando o conjunto (3, 11, 8747, 10169)
# Testando o conjunto (3, 11, 8747, 10243)
# Testando o conjunto (3, 11, 8747, 10333)
# Testando o conjunto (3, 11, 8747, 10357)
# Testando o conjunto (3, 11, 8747, 10459)
# Testando o conjunto (3, 11, 8747, 10567)
# Testando o conjunto (3, 11, 8747, 10627)
# Testando o conjunto (3, 11, 8747, 10771)
# Testando o conjunto (3, 11, 8747, 10889)
# Testando o conjunto (3, 11, 8747, 10987)
# Testando o conjunto (3, 11, 8747, 11027)
# Testando o conjunto (3, 11, 8747, 11197)
# Testando o conjunto (3, 17, 449, 2069)
# Testando o conjunto (3, 17, 449, 6353)
# Testando o conjunto (3, 17, 449, 6599)
# Testando o conjunto (3, 17, 449, 10091)
# Testando o conjunto (3, 17, 449, 10111)
# Testando o conjunto (3, 17, 449, 10169)
# Testando o conjunto (3, 17, 449, 10223)
# Testando o conjunto (3, 17, 449, 10243)
# Testando o conjunto (3, 17, 449, 10333)
# Testando o conjunto (3, 17, 449, 10357)
# Testando o conjunto (3, 17, 449, 10459)
# Testando o conjunto (3, 17, 449, 10567)
# Testando o conjunto (3, 17, 449, 10627)
# Testando o conjunto (3, 17, 449, 10771)
# Testando o conjunto (3, 17, 449, 10889)
# Testando o conjunto (3, 17, 449, 10987)
# Testando o conjunto (3, 17, 449, 11027)
# Testando o conjunto (3, 17, 449, 11173)
# Testando o conjunto (3, 17, 449, 11177)
# Testando o conjunto (3, 17, 449, 11197)
# Testando o conjunto (3, 17, 449, 11393)
# Testando o conjunto (3, 17, 449, 11447)
# Testando o conjunto (3, 17, 449, 11551)
# Testando o conjunto (3, 17, 449, 11821)
# Testando o conjunto (3, 17, 449, 11827)
# Testando o conjunto (3, 17, 449, 11867)
# Testando o conjunto (3, 17, 449, 11897)
# Testando o conjunto (3, 17, 449, 11981)
# Testando o conjunto (3, 17, 449, 12071)
# Testando o conjunto (3, 17, 449, 12101)
# Testando o conjunto (3, 17, 449, 12203)
# Testando o conjunto (3, 17, 449, 12253)
# Testando o conjunto (3, 17, 449, 12269)
# Testando o conjunto (3, 17, 449, 12343)
# Testando o conjunto (3, 17, 449, 12413)
# Testando o conjunto (3, 17, 449, 12451)
# Testando o conjunto (3, 17, 449, 12601)
# Testando o conjunto (3, 17, 449, 12703)
# Testando o conjunto (3, 17, 449, 12841)
# Testando o conjunto (3, 17, 449, 12899)
# Testando o conjunto (3, 17, 449, 12979)
# Testando o conjunto (3, 17, 449, 13381)
# Testando o conjunto (3, 17, 449, 13399)
# Testando o conjunto (3, 17, 449, 13553)
# Testando o conjunto (3, 17, 449, 13613)
# Testando o conjunto (3, 17, 449, 13619)
# Testando o conjunto (3, 17, 449, 13669)
# Testando o conjunto (3, 17, 449, 13763)
# Testando o conjunto (3, 17, 449, 13879)
# Testando o conjunto (3, 17, 449, 13931)
# Testando o conjunto (3, 17, 449, 13933)
# Testando o conjunto (3, 17, 449, 14107)
# Testando o conjunto (3, 17, 449, 14243)
# Testando o conjunto (3, 17, 449, 14401)
# Testando o conjunto (3, 17, 449, 14407)
# Testando o conjunto (3, 17, 449, 14543)
# Testando o conjunto (3, 17, 449, 14627)
# Testando o conjunto (3, 17, 449, 14779)
# Testando o conjunto (3, 17, 449, 14851)
# Testando o conjunto (3, 17, 449, 14879)
# Testando o conjunto (3, 17, 449, 15083)
# Testando o conjunto (3, 17, 449, 15313)
# Testando o conjunto (3, 17, 449, 15373)
# Testando o conjunto (3, 17, 449, 15461)
# Testando o conjunto (3, 17, 449, 15493)
# Testando o conjunto (3, 17, 449, 15559)
# Testando o conjunto (3, 17, 449, 15569)
# Testando o conjunto (3, 17, 449, 15739)
# Testando o conjunto (3, 17, 449, 15907)
# Testando o conjunto (3, 17, 449, 16339)
# Testando o conjunto (3, 17, 449, 16363)
# Testando o conjunto (3, 17, 449, 16567)
# Testando o conjunto (3, 17, 449, 16661)
# Testando o conjunto (3, 17, 449, 16703)
# Testando o conjunto (3, 17, 449, 16759)
# Testando o conjunto (3, 17, 449, 16937)
# Testando o conjunto (3, 17, 449, 17021)
# Testando o conjunto (3, 17, 449, 17029)
# Testando o conjunto (3, 17, 449, 17047)
# Testando o conjunto (3, 17, 449, 17077)
# Testando o conjunto (3, 17, 449, 17123)
# Testando o conjunto (3, 17, 449, 17209)
# Testando o conjunto (3, 17, 449, 17257)
# Testando o conjunto (3, 17, 449, 17327)
# Testando o conjunto (3, 17, 449, 17489)
# Testando o conjunto (3, 17, 449, 17539)
# Testando o conjunto (3, 17, 449, 17599)
# Testando o conjunto (3, 17, 449, 17789)
# Testando o conjunto (3, 17, 449, 17839)
# Testando o conjunto (3, 17, 449, 17903)
# Testando o conjunto (3, 17, 449, 17921)
# Testando o conjunto (3, 17, 449, 17923)
# Testando o conjunto (3, 17, 449, 17957)
# Testando o conjunto (3, 17, 449, 17959)
# Testando o conjunto (3, 17, 449, 18077)
# Testando o conjunto (3, 17, 449, 18127)
# Testando o conjunto (3, 17, 449, 18181)
# Testando o conjunto (3, 17, 449, 18191)
# Testando o conjunto (3, 17, 449, 18233)
# Testando o conjunto (3, 17, 449, 18289)
# Testando o conjunto (3, 17, 449, 18523)
# Testando o conjunto (3, 17, 449, 18679)
# Testando o conjunto (3, 17, 449, 18713)
# Testando o conjunto (3, 17, 449, 18743)
# Testando o conjunto (3, 17, 449, 19031)
# Testando o conjunto (3, 17, 449, 19183)
# Testando o conjunto (3, 17, 449, 19211)
# Testando o conjunto (3, 17, 449, 19237)
# Testando o conjunto (3, 17, 449, 19387)
# Testando o conjunto (3, 17, 449, 19441)
# Testando o conjunto (3, 17, 2069, 2297)
# Testando o conjunto (3, 17, 2069, 10091)
# Testando o conjunto (3, 17, 2069, 10111)
# Testando o conjunto (3, 17, 2069, 10169)
# Testando o conjunto (3, 17, 2069, 10243)
# Testando o conjunto (3, 17, 2069, 10333)
# Testando o conjunto (3, 17, 2069, 10357)
# Testando o conjunto (3, 17, 2069, 10459)
# Testando o conjunto (3, 17, 2069, 10567)
# Testando o conjunto (3, 17, 2069, 10627)
# Testando o conjunto (3, 17, 2069, 10771)
# Testando o conjunto (3, 17, 2069, 10889)
# Testando o conjunto (3, 17, 2069, 10987)
# Testando o conjunto (3, 17, 2069, 11027)
# Testando o conjunto (3, 17, 2069, 11197)
# Testando o conjunto (3, 17, 2069, 11393)
# Testando o conjunto (3, 17, 2069, 11447)
# Testando o conjunto (3, 17, 2069, 11551)
# Testando o conjunto (3, 17, 2069, 11827)
# Testando o conjunto (3, 17, 2069, 11867)
# Testando o conjunto (3, 17, 2069, 11897)
# Testando o conjunto (3, 17, 2069, 11981)
# Testando o conjunto (3, 17, 2069, 12071)
# Testando o conjunto (3, 17, 2069, 12101)
# Testando o conjunto (3, 17, 2069, 12203)
# Testando o conjunto (3, 17, 2069, 12253)
# Testando o conjunto (3, 17, 2069, 12269)
# Testando o conjunto (3, 17, 2069, 12343)
# Testando o conjunto (3, 17, 2069, 12413)
# Testando o conjunto (3, 17, 2069, 12451)
# Testando o conjunto (3, 17, 2069, 12601)
# Testando o conjunto (3, 17, 2069, 12703)
# Testando o conjunto (3, 17, 2069, 12841)
# Testando o conjunto (3, 17, 2069, 12899)
# Testando o conjunto (3, 17, 2069, 12979)
# Testando o conjunto (3, 17, 2069, 13381)
# Testando o conjunto (3, 17, 2069, 13399)
# Testando o conjunto (3, 17, 2069, 13553)
# Testando o conjunto (3, 17, 2069, 13619)
# Testando o conjunto (3, 17, 2069, 13669)
# Testando o conjunto (3, 17, 2069, 13763)
# Testando o conjunto (3, 17, 2069, 13879)
# Testando o conjunto (3, 17, 2069, 13933)
# Testando o conjunto (3, 17, 2069, 14107)
# Testando o conjunto (3, 17, 2069, 14243)
# Testando o conjunto (3, 17, 2069, 14407)
# Testando o conjunto (3, 17, 2069, 14543)
# Testando o conjunto (3, 17, 2069, 14627)
# Testando o conjunto (3, 17, 2069, 14779)
# Testando o conjunto (3, 17, 2069, 14851)
# Testando o conjunto (3, 17, 2069, 14879)
# Testando o conjunto (3, 17, 2069, 15083)
# Testando o conjunto (3, 17, 2069, 15313)
# Testando o conjunto (3, 17, 2069, 15373)
# Testando o conjunto (3, 17, 2069, 15461)
# Testando o conjunto (3, 17, 2069, 15493)
# Testando o conjunto (3, 17, 2069, 15569)
# Testando o conjunto (3, 17, 2069, 15739)
# Testando o conjunto (3, 17, 2069, 15907)
# Testando o conjunto (3, 17, 2069, 16339)
# Testando o conjunto (3, 17, 2069, 16363)
# Testando o conjunto (3, 17, 2069, 16567)
# Testando o conjunto (3, 17, 2069, 16661)
# Testando o conjunto (3, 17, 2069, 16703)
# Testando o conjunto (3, 17, 2069, 16759)
# Testando o conjunto (3, 17, 2069, 16937)
# Testando o conjunto (3, 17, 2069, 17021)
# Testando o conjunto (3, 17, 2069, 17029)
# Testando o conjunto (3, 17, 2069, 17047)
# Testando o conjunto (3, 17, 2069, 17077)
# Testando o conjunto (3, 17, 2069, 17123)
# Testando o conjunto (3, 17, 2069, 17209)
# Testando o conjunto (3, 17, 2069, 17257)
# Testando o conjunto (3, 17, 2069, 17327)
# Testando o conjunto (3, 17, 2069, 17489)
# Testando o conjunto (3, 17, 2069, 17539)
# Testando o conjunto (3, 17, 2069, 17599)
# Testando o conjunto (3, 17, 2069, 17789)
# Testando o conjunto (3, 17, 2069, 17839)
# Testando o conjunto (3, 17, 2069, 17903)
# Testando o conjunto (3, 17, 2213, 10091)
# Testando o conjunto (3, 17, 2213, 10111)
# Testando o conjunto (3, 17, 2213, 10169)
# Testando o conjunto (3, 17, 2213, 10243)
# Testando o conjunto (3, 17, 2213, 10333)
# Testando o conjunto (3, 17, 2213, 10357)
# Testando o conjunto (3, 17, 2213, 10459)
# Testando o conjunto (3, 17, 2213, 10567)
# Testando o conjunto (3, 17, 2213, 10627)
# Testando o conjunto (3, 17, 2213, 10771)
# Testando o conjunto (3, 17, 2213, 10889)
# Testando o conjunto (3, 17, 2213, 10987)
# Testando o conjunto (3, 17, 2213, 11027)
# Testando o conjunto (3, 17, 2213, 11197)
# Testando o conjunto (3, 17, 2213, 11393)
# Testando o conjunto (3, 17, 2213, 11447)
# Testando o conjunto (3, 17, 2213, 11551)
# Testando o conjunto (3, 17, 2213, 11827)
# Testando o conjunto (3, 17, 2213, 11867)
# Testando o conjunto (3, 17, 2213, 11897)
# Testando o conjunto (3, 17, 2213, 11981)
# Testando o conjunto (3, 17, 2213, 12071)
# Testando o conjunto (3, 17, 2213, 12101)
# Testando o conjunto (3, 17, 2213, 12203)
# Testando o conjunto (3, 17, 2213, 12253)
# Testando o conjunto (3, 17, 2213, 12269)
# Testando o conjunto (3, 17, 2213, 12343)
# Testando o conjunto (3, 17, 2213, 12413)
# Testando o conjunto (3, 17, 2213, 12451)
# Testando o conjunto (3, 17, 2213, 12601)
# Testando o conjunto (3, 17, 2213, 12703)
# Testando o conjunto (3, 17, 2213, 12841)
# Testando o conjunto (3, 17, 2213, 12899)
# Testando o conjunto (3, 17, 2213, 12979)
# Testando o conjunto (3, 17, 2213, 13381)
# Testando o conjunto (3, 17, 2213, 13399)
# Testando o conjunto (3, 17, 2213, 13553)
# Testando o conjunto (3, 17, 2213, 13619)
# Testando o conjunto (3, 17, 2213, 13669)
# Testando o conjunto (3, 17, 2213, 13763)
# Testando o conjunto (3, 17, 2213, 13879)
# Testando o conjunto (3, 17, 2213, 13933)
# Testando o conjunto (3, 17, 2213, 14107)
# Testando o conjunto (3, 17, 2213, 14243)
# Testando o conjunto (3, 17, 2213, 14407)
# Testando o conjunto (3, 17, 2213, 14543)
# Testando o conjunto (3, 17, 2213, 14627)
# Testando o conjunto (3, 17, 2213, 14779)
# Testando o conjunto (3, 17, 2213, 14851)
# Testando o conjunto (3, 17, 2213, 14879)
# Testando o conjunto (3, 17, 2213, 15083)
# Testando o conjunto (3, 17, 2213, 15313)
# Testando o conjunto (3, 17, 2213, 15373)
# Testando o conjunto (3, 17, 2213, 15461)
# Testando o conjunto (3, 17, 2213, 15493)
# Testando o conjunto (3, 17, 2213, 15569)
# Testando o conjunto (3, 17, 2213, 15739)
# Testando o conjunto (3, 17, 2213, 15907)
# Testando o conjunto (3, 17, 2213, 16339)
# Testando o conjunto (3, 17, 2213, 16363)
# Testando o conjunto (3, 17, 2213, 16567)
# Testando o conjunto (3, 17, 2213, 16661)
# Testando o conjunto (3, 17, 2213, 16703)
# Testando o conjunto (3, 17, 2213, 16759)
# Testando o conjunto (3, 17, 2213, 16937)
# Testando o conjunto (3, 17, 2213, 17021)
# Testando o conjunto (3, 17, 2213, 17029)
# Testando o conjunto (3, 17, 2213, 17047)
# Testando o conjunto (3, 17, 2213, 17077)
# Testando o conjunto (3, 17, 2213, 17123)
# Testando o conjunto (3, 17, 2213, 17209)
# Testando o conjunto (3, 17, 2213, 17257)
# Testando o conjunto (3, 17, 2213, 17327)
# Testando o conjunto (3, 17, 2213, 17489)
# Testando o conjunto (3, 17, 2213, 17539)
# Testando o conjunto (3, 17, 2213, 17599)
# Testando o conjunto (3, 17, 2297, 10091)
# Testando o conjunto (3, 17, 2297, 10111)
# Testando o conjunto (3, 17, 2297, 10169)
# Testando o conjunto (3, 17, 2297, 10243)
# Testando o conjunto (3, 17, 2297, 10333)
# Testando o conjunto (3, 17, 2297, 10357)
# Testando o conjunto (3, 17, 2297, 10459)
# Testando o conjunto (3, 17, 2297, 10567)
# Testando o conjunto (3, 17, 2297, 10627)
# Testando o conjunto (3, 17, 2297, 10771)
# Testando o conjunto (3, 17, 2297, 10889)
# Testando o conjunto (3, 17, 2297, 10987)
# Testando o conjunto (3, 17, 2297, 11027)
# Testando o conjunto (3, 17, 2297, 11197)
# Testando o conjunto (3, 17, 2297, 11393)
# Testando o conjunto (3, 17, 2297, 11447)
# Testando o conjunto (3, 17, 2297, 11551)
# Testando o conjunto (3, 17, 2297, 11827)
# Testando o conjunto (3, 17, 2297, 11867)
# Testando o conjunto (3, 17, 2297, 11897)
# Testando o conjunto (3, 17, 2297, 11981)
# Testando o conjunto (3, 17, 2297, 12071)
# Testando o conjunto (3, 17, 2297, 12101)
# Testando o conjunto (3, 17, 2297, 12203)
# Testando o conjunto (3, 17, 2297, 12253)
# Testando o conjunto (3, 17, 2297, 12269)
# Testando o conjunto (3, 17, 2297, 12343)
# Testando o conjunto (3, 17, 2297, 12413)
# Testando o conjunto (3, 17, 2297, 12451)
# Testando o conjunto (3, 17, 2297, 12601)
# Testando o conjunto (3, 17, 2297, 12703)
# Testando o conjunto (3, 17, 2297, 12841)
# Testando o conjunto (3, 17, 2297, 12899)
# Testando o conjunto (3, 17, 2297, 12979)
# Testando o conjunto (3, 17, 2297, 13381)
# Testando o conjunto (3, 17, 2297, 13399)
# Testando o conjunto (3, 17, 2297, 13553)
# Testando o conjunto (3, 17, 2297, 13619)
# Testando o conjunto (3, 17, 2297, 13669)
# Testando o conjunto (3, 17, 2297, 13763)
# Testando o conjunto (3, 17, 2297, 13879)
# Testando o conjunto (3, 17, 2297, 13933)
# Testando o conjunto (3, 17, 2297, 14107)
# Testando o conjunto (3, 17, 2297, 14243)
# Testando o conjunto (3, 17, 2297, 14407)
# Testando o conjunto (3, 17, 2297, 14543)
# Testando o conjunto (3, 17, 2297, 14627)
# Testando o conjunto (3, 17, 2297, 14779)
# Testando o conjunto (3, 17, 2297, 14851)
# Testando o conjunto (3, 17, 2297, 14879)
# Testando o conjunto (3, 17, 2297, 15083)
# Testando o conjunto (3, 17, 2297, 15313)
# Testando o conjunto (3, 17, 2297, 15373)
# Testando o conjunto (3, 17, 2297, 15461)
# Testando o conjunto (3, 17, 2297, 15493)
# Testando o conjunto (3, 17, 2297, 15569)
# Testando o conjunto (3, 17, 2297, 15739)
# Testando o conjunto (3, 17, 2297, 15907)
# Testando o conjunto (3, 17, 2297, 16339)
# Testando o conjunto (3, 17, 2297, 16363)
# Testando o conjunto (3, 17, 2297, 16567)
# Testando o conjunto (3, 17, 2297, 16661)
# Testando o conjunto (3, 17, 2297, 16703)
# Testando o conjunto (3, 17, 2297, 16759)
# Testando o conjunto (3, 17, 2297, 16937)
# Testando o conjunto (3, 17, 2297, 17021)
# Testando o conjunto (3, 17, 2297, 17029)
# Testando o conjunto (3, 17, 2297, 17047)
# Testando o conjunto (3, 17, 2297, 17077)
# Testando o conjunto (3, 17, 2297, 17123)
# Testando o conjunto (3, 17, 2297, 17209)
# Testando o conjunto (3, 17, 2297, 17257)
# Testando o conjunto (3, 17, 2297, 17327)
# Testando o conjunto (3, 17, 2297, 17489)
# Testando o conjunto (3, 17, 2297, 17539)
# Testando o conjunto (3, 17, 2297, 17599)
# Testando o conjunto (3, 17, 2411, 10091)
# Testando o conjunto (3, 17, 2411, 10111)
# Testando o conjunto (3, 17, 2411, 10169)
# Testando o conjunto (3, 17, 2411, 10243)
# Testando o conjunto (3, 17, 2411, 10333)
# Testando o conjunto (3, 17, 2411, 10357)
# Testando o conjunto (3, 17, 2411, 10459)
# Testando o conjunto (3, 17, 2411, 10567)
# Testando o conjunto (3, 17, 2411, 10627)
# Testando o conjunto (3, 17, 2411, 10771)
# Testando o conjunto (3, 17, 2411, 10889)
# Testando o conjunto (3, 17, 2411, 10987)
# Testando o conjunto (3, 17, 2411, 11027)
# Testando o conjunto (3, 17, 2411, 11197)
# Testando o conjunto (3, 17, 2411, 11393)
# Testando o conjunto (3, 17, 2411, 11447)
# Testando o conjunto (3, 17, 2411, 11551)
# Testando o conjunto (3, 17, 2411, 11827)
# Testando o conjunto (3, 17, 2411, 11867)
# Testando o conjunto (3, 17, 2411, 11897)
# Testando o conjunto (3, 17, 2411, 11981)
# Testando o conjunto (3, 17, 2411, 12071)
# Testando o conjunto (3, 17, 2411, 12101)
# Testando o conjunto (3, 17, 2411, 12203)
# Testando o conjunto (3, 17, 2411, 12253)
# Testando o conjunto (3, 17, 2411, 12269)
# Testando o conjunto (3, 17, 2411, 12343)
# Testando o conjunto (3, 17, 2411, 12413)
# Testando o conjunto (3, 17, 2411, 12451)
# Testando o conjunto (3, 17, 2411, 12601)
# Testando o conjunto (3, 17, 2411, 12703)
# Testando o conjunto (3, 17, 2411, 12841)
# Testando o conjunto (3, 17, 2411, 12899)
# Testando o conjunto (3, 17, 2411, 12979)
# Testando o conjunto (3, 17, 2411, 13381)
# Testando o conjunto (3, 17, 2411, 13399)
# Testando o conjunto (3, 17, 2411, 13553)
# Testando o conjunto (3, 17, 2411, 13619)
# Testando o conjunto (3, 17, 2411, 13669)
# Testando o conjunto (3, 17, 2411, 13763)
# Testando o conjunto (3, 17, 2411, 13879)
# Testando o conjunto (3, 17, 2411, 13933)
# Testando o conjunto (3, 17, 2411, 14107)
# Testando o conjunto (3, 17, 2411, 14243)
# Testando o conjunto (3, 17, 2411, 14407)
# Testando o conjunto (3, 17, 2411, 14543)
# Testando o conjunto (3, 17, 2411, 14627)
# Testando o conjunto (3, 17, 2411, 14779)
# Testando o conjunto (3, 17, 2411, 14851)
# Testando o conjunto (3, 17, 2411, 14879)
# Testando o conjunto (3, 17, 2411, 15083)
# Testando o conjunto (3, 17, 2411, 15313)
# Testando o conjunto (3, 17, 2411, 15373)
# Testando o conjunto (3, 17, 2411, 15461)
# Testando o conjunto (3, 17, 2411, 15493)
# Testando o conjunto (3, 17, 2411, 15569)
# Testando o conjunto (3, 17, 2411, 15739)
# Testando o conjunto (3, 17, 2411, 15907)
# Testando o conjunto (3, 17, 2411, 16339)
# Testando o conjunto (3, 17, 2411, 16363)
# Testando o conjunto (3, 17, 2411, 16567)
# Testando o conjunto (3, 17, 2411, 16661)
# Testando o conjunto (3, 17, 2411, 16703)
# Testando o conjunto (3, 17, 2411, 16759)
# Testando o conjunto (3, 17, 2411, 16937)
# Testando o conjunto (3, 17, 2411, 17021)
# Testando o conjunto (3, 17, 2411, 17029)
# Testando o conjunto (3, 17, 2411, 17047)
# Testando o conjunto (3, 17, 2411, 17077)
# Testando o conjunto (3, 17, 2411, 17123)
# Testando o conjunto (3, 17, 2411, 17209)
# Testando o conjunto (3, 17, 2411, 17257)
# Testando o conjunto (3, 17, 2411, 17327)
# Testando o conjunto (3, 17, 2411, 17489)
# Testando o conjunto (3, 17, 2411, 17539)
# Testando o conjunto (3, 17, 4019, 10091)
# Testando o conjunto (3, 17, 4019, 10111)
# Testando o conjunto (3, 17, 4019, 10169)
# Testando o conjunto (3, 17, 4019, 10243)
# Testando o conjunto (3, 17, 4019, 10333)
# Testando o conjunto (3, 17, 4019, 10357)
# Testando o conjunto (3, 17, 4019, 10459)
# Testando o conjunto (3, 17, 4019, 10567)
# Testando o conjunto (3, 17, 4019, 10627)
# Testando o conjunto (3, 17, 4019, 10771)
# Testando o conjunto (3, 17, 4019, 10889)
# Testando o conjunto (3, 17, 4019, 10987)
# Testando o conjunto (3, 17, 4019, 11027)
# Testando o conjunto (3, 17, 4019, 11197)
# Testando o conjunto (3, 17, 4019, 11393)
# Testando o conjunto (3, 17, 4019, 11447)
# Testando o conjunto (3, 17, 4019, 11551)
# Testando o conjunto (3, 17, 4019, 11827)
# Testando o conjunto (3, 17, 4019, 11867)
# Testando o conjunto (3, 17, 4019, 11897)
# Testando o conjunto (3, 17, 4019, 11981)
# Testando o conjunto (3, 17, 4019, 12071)
# Testando o conjunto (3, 17, 4019, 12101)
# Testando o conjunto (3, 17, 4019, 12203)
# Testando o conjunto (3, 17, 4019, 12253)
# Testando o conjunto (3, 17, 4019, 12269)
# Testando o conjunto (3, 17, 4019, 12343)
# Testando o conjunto (3, 17, 4019, 12413)
# Testando o conjunto (3, 17, 4019, 12451)
# Testando o conjunto (3, 17, 4019, 12601)
# Testando o conjunto (3, 17, 4019, 12703)
# Testando o conjunto (3, 17, 4019, 12841)
# Testando o conjunto (3, 17, 4019, 12899)
# Testando o conjunto (3, 17, 4019, 12979)
# Testando o conjunto (3, 17, 4019, 13381)
# Testando o conjunto (3, 17, 4019, 13399)
# Testando o conjunto (3, 17, 4019, 13553)
# Testando o conjunto (3, 17, 4019, 13619)
# Testando o conjunto (3, 17, 4019, 13669)
# Testando o conjunto (3, 17, 4019, 13763)
# Testando o conjunto (3, 17, 4019, 13879)
# Testando o conjunto (3, 17, 4019, 13933)
# Testando o conjunto (3, 17, 4019, 14107)
# Testando o conjunto (3, 17, 4019, 14243)
# Testando o conjunto (3, 17, 4019, 14407)
# Testando o conjunto (3, 17, 4019, 14543)
# Testando o conjunto (3, 17, 4019, 14627)
# Testando o conjunto (3, 17, 4019, 14779)
# Testando o conjunto (3, 17, 4019, 14851)
# Testando o conjunto (3, 17, 4019, 14879)
# Testando o conjunto (3, 17, 4019, 15083)
# Testando o conjunto (3, 17, 4019, 15313)
# Testando o conjunto (3, 17, 4019, 15373)
# Testando o conjunto (3, 17, 4019, 15461)
# Testando o conjunto (3, 17, 4019, 15493)
# Testando o conjunto (3, 17, 4019, 15569)
# Testando o conjunto (3, 17, 4019, 15739)
# Testando o conjunto (3, 17, 4019, 15907)
# Testando o conjunto (3, 17, 4583, 10091)
# Testando o conjunto (3, 17, 4583, 10111)
# Testando o conjunto (3, 17, 4583, 10169)
# Testando o conjunto (3, 17, 4583, 10243)
# Testando o conjunto (3, 17, 4583, 10333)
# Testando o conjunto (3, 17, 4583, 10357)
# Testando o conjunto (3, 17, 4583, 10459)
# Testando o conjunto (3, 17, 4583, 10567)
# Testando o conjunto (3, 17, 4583, 10627)
# Testando o conjunto (3, 17, 4583, 10771)
# Testando o conjunto (3, 17, 4583, 10889)
# Testando o conjunto (3, 17, 4583, 10987)
# Testando o conjunto (3, 17, 4583, 11027)
# Testando o conjunto (3, 17, 4583, 11197)
# Testando o conjunto (3, 17, 4583, 11393)
# Testando o conjunto (3, 17, 4583, 11447)
# Testando o conjunto (3, 17, 4583, 11551)
# Testando o conjunto (3, 17, 4583, 11827)
# Testando o conjunto (3, 17, 4583, 11867)
# Testando o conjunto (3, 17, 4583, 11897)
# Testando o conjunto (3, 17, 4583, 11981)
# Testando o conjunto (3, 17, 4583, 12071)
# Testando o conjunto (3, 17, 4583, 12101)
# Testando o conjunto (3, 17, 4583, 12203)
# Testando o conjunto (3, 17, 4583, 12253)
# Testando o conjunto (3, 17, 4583, 12269)
# Testando o conjunto (3, 17, 4583, 12343)
# Testando o conjunto (3, 17, 4583, 12413)
# Testando o conjunto (3, 17, 4583, 12451)
# Testando o conjunto (3, 17, 4583, 12601)
# Testando o conjunto (3, 17, 4583, 12703)
# Testando o conjunto (3, 17, 4583, 12841)
# Testando o conjunto (3, 17, 4583, 12899)
# Testando o conjunto (3, 17, 4583, 12979)
# Testando o conjunto (3, 17, 4583, 13381)
# Testando o conjunto (3, 17, 4583, 13399)
# Testando o conjunto (3, 17, 4583, 13553)
# Testando o conjunto (3, 17, 4583, 13619)
# Testando o conjunto (3, 17, 4583, 13669)
# Testando o conjunto (3, 17, 4583, 13763)
# Testando o conjunto (3, 17, 4583, 13879)
# Testando o conjunto (3, 17, 4583, 13933)
# Testando o conjunto (3, 17, 4583, 14107)
# Testando o conjunto (3, 17, 4583, 14243)
# Testando o conjunto (3, 17, 4583, 14407)
# Testando o conjunto (3, 17, 4583, 14543)
# Testando o conjunto (3, 17, 4583, 14627)
# Testando o conjunto (3, 17, 4583, 14779)
# Testando o conjunto (3, 17, 4583, 14851)
# Testando o conjunto (3, 17, 4583, 14879)
# Testando o conjunto (3, 17, 4583, 15083)
# Testando o conjunto (3, 17, 4583, 15313)
# Testando o conjunto (3, 17, 4583, 15373)
# Testando o conjunto (3, 17, 6353, 10091)
# Testando o conjunto (3, 17, 6353, 10111)
# Testando o conjunto (3, 17, 6353, 10169)
# Testando o conjunto (3, 17, 6353, 10243)
# Testando o conjunto (3, 17, 6353, 10333)
# Testando o conjunto (3, 17, 6353, 10357)
# Testando o conjunto (3, 17, 6353, 10459)
# Testando o conjunto (3, 17, 6353, 10567)
# Testando o conjunto (3, 17, 6353, 10627)
# Testando o conjunto (3, 17, 6353, 10771)
# Testando o conjunto (3, 17, 6353, 10889)
# Testando o conjunto (3, 17, 6353, 10987)
# Testando o conjunto (3, 17, 6353, 11027)
# Testando o conjunto (3, 17, 6353, 11197)
# Testando o conjunto (3, 17, 6353, 11393)
# Testando o conjunto (3, 17, 6353, 11447)
# Testando o conjunto (3, 17, 6353, 11551)
# Testando o conjunto (3, 17, 6353, 11827)
# Testando o conjunto (3, 17, 6353, 11867)
# Testando o conjunto (3, 17, 6353, 11897)
# Testando o conjunto (3, 17, 6353, 11981)
# Testando o conjunto (3, 17, 6353, 12071)
# Testando o conjunto (3, 17, 6353, 12101)
# Testando o conjunto (3, 17, 6353, 12203)
# Testando o conjunto (3, 17, 6353, 12253)
# Testando o conjunto (3, 17, 6353, 12269)
# Testando o conjunto (3, 17, 6353, 12343)
# Testando o conjunto (3, 17, 6353, 12413)
# Testando o conjunto (3, 17, 6353, 12451)
# Testando o conjunto (3, 17, 6353, 12601)
# Testando o conjunto (3, 17, 6353, 12703)
# Testando o conjunto (3, 17, 6353, 12841)
# Testando o conjunto (3, 17, 6353, 12899)
# Testando o conjunto (3, 17, 6353, 12979)
# Testando o conjunto (3, 17, 6353, 13381)
# Testando o conjunto (3, 17, 6353, 13399)
# Testando o conjunto (3, 17, 6353, 13553)
# Testando o conjunto (3, 17, 6353, 13619)
# Testando o conjunto (3, 17, 6599, 10091)
# Testando o conjunto (3, 17, 6599, 10111)
# Testando o conjunto (3, 17, 6599, 10169)
# Testando o conjunto (3, 17, 6599, 10243)
# Testando o conjunto (3, 17, 6599, 10333)
# Testando o conjunto (3, 17, 6599, 10357)
# Testando o conjunto (3, 17, 6599, 10459)
# Testando o conjunto (3, 17, 6599, 10567)
# Testando o conjunto (3, 17, 6599, 10627)
# Testando o conjunto (3, 17, 6599, 10771)
# Testando o conjunto (3, 17, 6599, 10889)
# Testando o conjunto (3, 17, 6599, 10987)
# Testando o conjunto (3, 17, 6599, 11027)
# Testando o conjunto (3, 17, 6599, 11197)
# Testando o conjunto (3, 17, 6599, 11393)
# Testando o conjunto (3, 17, 6599, 11447)
# Testando o conjunto (3, 17, 6599, 11551)
# Testando o conjunto (3, 17, 6599, 11827)
# Testando o conjunto (3, 17, 6599, 11867)
# Testando o conjunto (3, 17, 6599, 11897)
# Testando o conjunto (3, 17, 6599, 11981)
# Testando o conjunto (3, 17, 6599, 12071)
# Testando o conjunto (3, 17, 6599, 12101)
# Testando o conjunto (3, 17, 6599, 12203)
# Testando o conjunto (3, 17, 6599, 12253)
# Testando o conjunto (3, 17, 6599, 12269)
# Testando o conjunto (3, 17, 6599, 12343)
# Testando o conjunto (3, 17, 6599, 12413)
# Testando o conjunto (3, 17, 6599, 12451)
# Testando o conjunto (3, 17, 6599, 12601)
# Testando o conjunto (3, 17, 6599, 12703)
# Testando o conjunto (3, 17, 6599, 12841)
# Testando o conjunto (3, 17, 6599, 12899)
# Testando o conjunto (3, 17, 6599, 12979)
# Testando o conjunto (3, 17, 6599, 13381)
# Testando o conjunto (3, 17, 6899, 10091)
# Testando o conjunto (3, 17, 6899, 10111)
# Testando o conjunto (3, 17, 6899, 10169)
# Testando o conjunto (3, 17, 6899, 10243)
# Testando o conjunto (3, 17, 6899, 10333)
# Testando o conjunto (3, 17, 6899, 10357)
# Testando o conjunto (3, 17, 6899, 10459)
# Testando o conjunto (3, 17, 6899, 10567)
# Testando o conjunto (3, 17, 6899, 10627)
# Testando o conjunto (3, 17, 6899, 10771)
# Testando o conjunto (3, 17, 6899, 10889)
# Testando o conjunto (3, 17, 6899, 10987)
# Testando o conjunto (3, 17, 6899, 11027)
# Testando o conjunto (3, 17, 6899, 11197)
# Testando o conjunto (3, 17, 6899, 11393)
# Testando o conjunto (3, 17, 6899, 11447)
# Testando o conjunto (3, 17, 6899, 11551)
# Testando o conjunto (3, 17, 6899, 11827)
# Testando o conjunto (3, 17, 6899, 11867)
# Testando o conjunto (3, 17, 6899, 11897)
# Testando o conjunto (3, 17, 6899, 11981)
# Testando o conjunto (3, 17, 6899, 12071)
# Testando o conjunto (3, 17, 6899, 12101)
# Testando o conjunto (3, 17, 6899, 12203)
# Testando o conjunto (3, 17, 6899, 12253)
# Testando o conjunto (3, 17, 6899, 12269)
# Testando o conjunto (3, 17, 6899, 12343)
# Testando o conjunto (3, 17, 6899, 12413)
# Testando o conjunto (3, 17, 6899, 12451)
# Testando o conjunto (3, 17, 6899, 12601)
# Testando o conjunto (3, 17, 6899, 12703)
# Testando o conjunto (3, 17, 6899, 12841)
# Testando o conjunto (3, 17, 6899, 12899)
# Testando o conjunto (3, 17, 6899, 12979)
# Testando o conjunto (3, 17, 7691, 10091)
# Testando o conjunto (3, 17, 7691, 10111)
# Testando o conjunto (3, 17, 7691, 10169)
# Testando o conjunto (3, 17, 7691, 10243)
# Testando o conjunto (3, 17, 7691, 10333)
# Testando o conjunto (3, 17, 7691, 10357)
# Testando o conjunto (3, 17, 7691, 10459)
# ...
# Testando o conjunto (3, 1667, 5573, 11447)
# Testando o conjunto (3, 1667, 5573, 11551)
# Testando o conjunto (3, 1667, 5573, 11827)
# Testando o conjunto (3, 1667, 5573, 11867)
# Testando o conjunto (3, 1667, 5573, 11897)
# Testando o conjunto (3, 1667, 5573, 11981)
# Testando o conjunto (3, 1667, 5573, 12071)
# Testando o conjunto (3, 1667, 5573, 12101)
# Testando o conjunto (3, 1667, 5573, 12203)
# Testando o conjunto (3, 1667, 5573, 12253)
# Testando o conjunto (3, 1667, 5573, 12269)
# Testando o conjunto (3, 1667, 5573, 12343)
# Testando o conjunto (3, 1667, 5573, 12413)
# Testando o conjunto (3, 1667, 5573, 12451)
# Testando o conjunto (3, 1667, 5573, 12601)
# Testando o conjunto (3, 1667, 5573, 12703)
# Testando o conjunto (3, 1667, 6353, 10091)
# Testando o conjunto (3, 1667, 6353, 10111)
# Testando o conjunto (3, 1667, 6353, 10169)
# Testando o conjunto (3, 1667, 6353, 10243)
# Testando o conjunto (3, 1667, 6353, 10333)
# Testando o conjunto (3, 1667, 6353, 10357)
# Testando o conjunto (3, 1667, 6353, 10459)
# Testando o conjunto (3, 1667, 6353, 10567)
# Testando o conjunto (3, 1667, 6353, 10627)
# Testando o conjunto (3, 1667, 6353, 10771)
# Testando o conjunto (3, 1667, 6353, 10889)
# Testando o conjunto (3, 1667, 6353, 10987)
# Testando o conjunto (3, 1667, 6353, 11027)
# Testando o conjunto (3, 1667, 6353, 11197)
# Testando o conjunto (3, 1667, 6353, 11393)
# Testando o conjunto (3, 1667, 6353, 11447)
# Testando o conjunto (3, 1667, 6353, 11551)
# Testando o conjunto (3, 1667, 6353, 11827)
# Testando o conjunto (3, 1667, 6353, 11867)
# Testando o conjunto (3, 1667, 6353, 11897)
# Testando o conjunto (3, 1699, 6571, 8713)
# Testando o conjunto (3, 1699, 6571, 10091)
# Testando o conjunto (3, 1699, 6571, 10111)
# Testando o conjunto (3, 1699, 6571, 10169)
# Testando o conjunto (3, 1699, 6571, 10223)
# Testando o conjunto (3, 1699, 6571, 10243)
# Testando o conjunto (3, 1699, 6571, 10333)
# Testando o conjunto (3, 1699, 6571, 10357)
# Testando o conjunto (3, 1699, 6571, 10459)
# Testando o conjunto (3, 1699, 6571, 10567)
# Testando o conjunto (3, 1699, 6571, 10627)
# Testando o conjunto (3, 1699, 6571, 10771)
# Testando o conjunto (3, 1699, 6571, 10889)
# Testando o conjunto (3, 1699, 6571, 10987)
# Testando o conjunto (3, 1699, 6571, 11027)
# Testando o conjunto (3, 1699, 6571, 11173)
# Testando o conjunto (3, 1699, 6571, 11177)
# Testando o conjunto (3, 1699, 6571, 11197)
# Testando o conjunto (3, 1699, 6571, 11393)
# Testando o conjunto (3, 1699, 6571, 11447)
# Testando o conjunto (3, 1699, 6571, 11551)
# Testando o conjunto (3, 1907, 5099, 10091)
# Testando o conjunto (3, 1907, 5099, 10111)
# Testando o conjunto (3, 1907, 5099, 10169)
# Testando o conjunto (3, 1907, 5099, 10223)
# Testando o conjunto (3, 1907, 5099, 10243)
# Testando o conjunto (3, 1907, 5099, 10333)
# Testando o conjunto (3, 1907, 5099, 10357)
# Testando o conjunto (3, 1907, 5099, 10459)
# Testando o conjunto (3, 1907, 5099, 10567)
# Testando o conjunto (3, 1907, 5099, 10627)
# Testando o conjunto (3, 1907, 5099, 10771)
# Testando o conjunto (3, 1907, 5099, 10889)
# Testando o conjunto (3, 1907, 5099, 10987)
# Testando o conjunto (3, 1907, 5099, 11027)
# Testando o conjunto (3, 1907, 5099, 11173)
# Testando o conjunto (3, 1907, 5099, 11177)
# Testando o conjunto (3, 1907, 5099, 11197)
# Testando o conjunto (3, 1907, 5099, 11393)
# Testando o conjunto (3, 1907, 5099, 11447)
# Testando o conjunto (3, 1907, 5099, 11551)
# Testando o conjunto (3, 1907, 5099, 11821)
# Testando o conjunto (3, 1907, 5099, 11827)
# Testando o conjunto (3, 1907, 5099, 11867)
# Testando o conjunto (3, 1907, 5099, 11897)
# Testando o conjunto (3, 1907, 5099, 11981)
# Testando o conjunto (3, 1907, 5099, 12071)
# Testando o conjunto (3, 1907, 5099, 12101)
# Testando o conjunto (3, 1907, 5099, 12203)
# Testando o conjunto (3, 1907, 5099, 12253)
# Testando o conjunto (3, 1907, 5099, 12269)
# Testando o conjunto (3, 1907, 5099, 12343)
# Testando o conjunto (3, 1907, 5099, 12413)
# Testando o conjunto (3, 1907, 5099, 12451)
# Testando o conjunto (3, 1907, 5099, 12601)
# Testando o conjunto (3, 1907, 5099, 12703)
# Testando o conjunto (3, 1907, 5099, 12841)
# Testando o conjunto (3, 1907, 5099, 12899)
# Testando o conjunto (3, 1907, 5099, 12979)
# Testando o conjunto (3, 2069, 2297, 10091)
# Testando o conjunto (3, 2069, 2297, 10111)
# Testando o conjunto (3, 2069, 2297, 10169)
# Testando o conjunto (3, 2069, 2297, 10223)
# Testando o conjunto (3, 2069, 2297, 10243)
# Testando o conjunto (3, 2069, 2297, 10333)
# Testando o conjunto (3, 2069, 2297, 10357)
# Testando o conjunto (3, 2069, 2297, 10459)
# Testando o conjunto (3, 2069, 2297, 10567)
# Testando o conjunto (3, 2069, 2297, 10627)
# Testando o conjunto (3, 2069, 2297, 10771)
# Testando o conjunto (3, 2069, 2297, 10889)
# Testando o conjunto (3, 2069, 2297, 10987)
# Testando o conjunto (3, 2069, 2297, 11027)
# Testando o conjunto (3, 2069, 2297, 11173)
# Testando o conjunto (3, 2069, 2297, 11177)
# Testando o conjunto (3, 2069, 2297, 11197)
# Testando o conjunto (3, 2069, 2297, 11393)
# Testando o conjunto (3, 2069, 2297, 11447)
# Testando o conjunto (3, 2069, 2297, 11551)
# Testando o conjunto (3, 2069, 2297, 11821)
# Testando o conjunto (3, 2069, 2297, 11827)
# Testando o conjunto (3, 2069, 2297, 11867)
# Testando o conjunto (3, 2069, 2297, 11897)
# Testando o conjunto (3, 2069, 2297, 11981)
# Testando o conjunto (3, 2069, 2297, 12071)
# Testando o conjunto (3, 2069, 2297, 12101)
# Testando o conjunto (3, 2069, 2297, 12203)
# Testando o conjunto (3, 2069, 2297, 12253)
# Testando o conjunto (3, 2069, 2297, 12269)
# Testando o conjunto (3, 2069, 2297, 12343)
# Testando o conjunto (3, 2069, 2297, 12413)
# Testando o conjunto (3, 2069, 2297, 12451)
# Testando o conjunto (3, 2069, 2297, 12601)
# Testando o conjunto (3, 2069, 2297, 12703)
# Testando o conjunto (3, 2069, 2297, 12841)
# Testando o conjunto (3, 2069, 2297, 12899)
# Testando o conjunto (3, 2069, 2297, 12979)
# Testando o conjunto (3, 2069, 2297, 13381)
# Testando o conjunto (3, 2069, 2297, 13399)
# Testando o conjunto (3, 2069, 2297, 13553)
# Testando o conjunto (3, 2069, 2297, 13613)
# Testando o conjunto (3, 2069, 2297, 13619)
# Testando o conjunto (3, 2069, 2297, 13669)
# Testando o conjunto (3, 2069, 2297, 13763)
# Testando o conjunto (3, 2069, 2297, 13879)
# Testando o conjunto (3, 2069, 2297, 13931)
# Testando o conjunto (3, 2069, 2297, 13933)
# Testando o conjunto (3, 2069, 2297, 14107)
# Testando o conjunto (3, 2069, 2297, 14243)
# Testando o conjunto (3, 2069, 2297, 14401)
# Testando o conjunto (3, 2069, 2297, 14407)
# Testando o conjunto (3, 2069, 2297, 14543)
# Testando o conjunto (3, 2069, 2297, 14627)
# Testando o conjunto (3, 2069, 2297, 14779)
# Testando o conjunto (3, 2069, 2297, 14851)
# Testando o conjunto (3, 2069, 2297, 14879)
# Testando o conjunto (3, 2069, 2297, 15083)
# Testando o conjunto (3, 2069, 2297, 15313)
# Testando o conjunto (3, 2069, 2297, 15373)
# Testando o conjunto (3, 2069, 2297, 15461)
# Testando o conjunto (3, 2069, 2297, 15493)
# Testando o conjunto (3, 2069, 2297, 15559)
# Testando o conjunto (3, 2069, 2297, 15569)
# Testando o conjunto (3, 2069, 7253, 10091)
# Testando o conjunto (3, 2069, 7253, 10111)
# Testando o conjunto (3, 2069, 7253, 10169)
# Testando o conjunto (3, 2069, 7253, 10243)
# Testando o conjunto (3, 2069, 7253, 10333)
# Testando o conjunto (3, 2069, 7253, 10357)
# Testando o conjunto (3, 2069, 7253, 10459)
# Testando o conjunto (3, 2069, 7253, 10567)
# Testando o conjunto (3, 2069, 7253, 10627)
# Testando o conjunto (3, 2143, 6871, 10091)
# Testando o conjunto (3, 2143, 6871, 10111)
# Testando o conjunto (3, 2143, 6871, 10169)
# Testando o conjunto (3, 2143, 6871, 10223)
# Testando o conjunto (3, 2143, 6871, 10243)
# Testando o conjunto (3, 2143, 6871, 10333)
# Testando o conjunto (3, 2143, 6871, 10357)
# Testando o conjunto (3, 2143, 6871, 10459)
# Testando o conjunto (3, 2143, 6871, 10567)
# Testando o conjunto (3, 2143, 6871, 10627)
# Testando o conjunto (3, 2143, 6871, 10771)
# Testando o conjunto (3, 2143, 6871, 10889)
# Testando o conjunto (3, 2213, 4253, 10091)
# Testando o conjunto (3, 2213, 4253, 10111)
# Testando o conjunto (3, 2213, 4253, 10169)
# Testando o conjunto (3, 2213, 4253, 10223)
# Testando o conjunto (3, 2213, 4253, 10243)
# Testando o conjunto (3, 2213, 4253, 10333)
# Testando o conjunto (3, 2213, 4253, 10357)
# Testando o conjunto (3, 2213, 4253, 10459)
# Testando o conjunto (3, 2213, 4253, 10567)
# Testando o conjunto (3, 2213, 4253, 10627)
# Testando o conjunto (3, 2213, 4253, 10771)
# Testando o conjunto (3, 2213, 4253, 10889)
# Testando o conjunto (3, 2213, 4253, 10987)
# Testando o conjunto (3, 2213, 4253, 11027)
# Testando o conjunto (3, 2213, 4253, 11173)
# Testando o conjunto (3, 2213, 4253, 11177)
# Testando o conjunto (3, 2213, 4253, 11197)
# Testando o conjunto (3, 2213, 4253, 11393)
# Testando o conjunto (3, 2213, 4253, 11447)
# Testando o conjunto (3, 2213, 4253, 11551)
# Testando o conjunto (3, 2213, 4253, 11821)
# Testando o conjunto (3, 2213, 4253, 11827)
# Testando o conjunto (3, 2213, 4253, 11867)
# Testando o conjunto (3, 2213, 4253, 11897)
# Testando o conjunto (3, 2213, 4253, 11981)
# Testando o conjunto (3, 2213, 4253, 12071)
# Testando o conjunto (3, 2213, 4253, 12101)
# Testando o conjunto (3, 2213, 4253, 12203)
# Testando o conjunto (3, 2213, 4253, 12253)
# Testando o conjunto (3, 2213, 4253, 12269)
# Testando o conjunto (3, 2213, 4253, 12343)
# Testando o conjunto (3, 2213, 4253, 12413)
# Testando o conjunto (3, 2213, 4253, 12451)
# Testando o conjunto (3, 2213, 4253, 12601)
# Testando o conjunto (3, 2213, 4253, 12703)
# Testando o conjunto (3, 2213, 4253, 12841)
# Testando o conjunto (3, 2213, 4253, 12899)
# Testando o conjunto (3, 2213, 4253, 12979)
# Testando o conjunto (3, 2213, 4253, 13381)
# Testando o conjunto (3, 2213, 4253, 13399)
# Testando o conjunto (3, 2297, 2381, 10091)
# Testando o conjunto (3, 2297, 2381, 10111)
# Testando o conjunto (3, 2297, 2381, 10169)
# Testando o conjunto (3, 2297, 2381, 10223)
# Testando o conjunto (3, 2297, 2381, 10243)
# Testando o conjunto (3, 2297, 2381, 10333)
# Testando o conjunto (3, 2297, 2381, 10357)
# Testando o conjunto (3, 2297, 2381, 10459)
# Testando o conjunto (3, 2297, 2381, 10567)
# Testando o conjunto (3, 2297, 2381, 10627)
# Testando o conjunto (3, 2297, 2381, 10771)
# Testando o conjunto (3, 2297, 2381, 10889)
# Testando o conjunto (3, 2297, 2381, 10987)
# Testando o conjunto (3, 2297, 2381, 11027)
# Testando o conjunto (3, 2297, 2381, 11173)
# Testando o conjunto (3, 2297, 2381, 11177)
# Testando o conjunto (3, 2297, 2381, 11197)
# Testando o conjunto (3, 2297, 2381, 11393)
# Testando o conjunto (3, 2297, 2381, 11447)
# Testando o conjunto (3, 2297, 2381, 11551)
# Testando o conjunto (3, 2297, 2381, 11821)
# Testando o conjunto (3, 2297, 2381, 11827)
# Testando o conjunto (3, 2297, 2381, 11867)
# Testando o conjunto (3, 2297, 2381, 11897)
# Testando o conjunto (3, 2297, 2381, 11981)
# Testando o conjunto (3, 2297, 2381, 12071)
# Testando o conjunto (3, 2297, 2381, 12101)
# Testando o conjunto (3, 2297, 2381, 12203)
# Testando o conjunto (3, 2297, 2381, 12253)
# Testando o conjunto (3, 2297, 2381, 12269)
# Testando o conjunto (3, 2297, 2381, 12343)
# Testando o conjunto (3, 2297, 2381, 12413)
# Testando o conjunto (3, 2297, 2381, 12451)
# Testando o conjunto (3, 2297, 2381, 12601)
# Testando o conjunto (3, 2297, 2381, 12703)
# Testando o conjunto (3, 2297, 2381, 12841)
# Testando o conjunto (3, 2297, 2381, 12899)
# Testando o conjunto (3, 2297, 2381, 12979)
# Testando o conjunto (3, 2297, 2381, 13381)
# Testando o conjunto (3, 2297, 2381, 13399)
# Testando o conjunto (3, 2297, 2381, 13553)
# Testando o conjunto (3, 2297, 2381, 13613)
# Testando o conjunto (3, 2297, 2381, 13619)
# Testando o conjunto (3, 2297, 2381, 13669)
# Testando o conjunto (3, 2297, 2381, 13763)
# Testando o conjunto (3, 2297, 2381, 13879)
# Testando o conjunto (3, 2297, 2381, 13931)
# Testando o conjunto (3, 2297, 2381, 13933)
# Testando o conjunto (3, 2297, 2381, 14107)
# Testando o conjunto (3, 2297, 2381, 14243)
# Testando o conjunto (3, 2297, 2381, 14401)
# Testando o conjunto (3, 2297, 2381, 14407)
# Testando o conjunto (3, 2297, 2381, 14543)
# Testando o conjunto (3, 2297, 2381, 14627)
# Testando o conjunto (3, 2297, 2381, 14779)
# Testando o conjunto (3, 2297, 2381, 14851)
# Testando o conjunto (3, 2297, 2381, 14879)
# Testando o conjunto (3, 2297, 2381, 15083)
# Testando o conjunto (3, 2297, 2381, 15313)
# Testando o conjunto (3, 2377, 4159, 10091)
# Testando o conjunto (3, 2377, 4159, 10111)
# Testando o conjunto (3, 2377, 4159, 10169)
# Testando o conjunto (3, 2377, 4159, 10223)
# Testando o conjunto (3, 2377, 4159, 10243)
# Testando o conjunto (3, 2377, 4159, 10333)
# Testando o conjunto (3, 2377, 4159, 10357)
# Testando o conjunto (3, 2377, 4159, 10459)
# Testando o conjunto (3, 2377, 4159, 10567)
# Testando o conjunto (3, 2377, 4159, 10627)
# Testando o conjunto (3, 2377, 4159, 10771)
# Testando o conjunto (3, 2377, 4159, 10889)
# Testando o conjunto (3, 2377, 4159, 10987)
# Testando o conjunto (3, 2377, 4159, 11027)
# Testando o conjunto (3, 2377, 4159, 11173)
# Testando o conjunto (3, 2377, 4159, 11177)
# Testando o conjunto (3, 2377, 4159, 11197)
# Testando o conjunto (3, 2377, 4159, 11393)
# Testando o conjunto (3, 2377, 4159, 11447)
# Testando o conjunto (3, 2377, 4159, 11551)
# Testando o conjunto (3, 2377, 4159, 11821)
# Testando o conjunto (3, 2377, 4159, 11827)
# Testando o conjunto (3, 2377, 4159, 11867)
# Testando o conjunto (3, 2377, 4159, 11897)
# Testando o conjunto (3, 2377, 4159, 11981)
# Testando o conjunto (3, 2377, 4159, 12071)
# Testando o conjunto (3, 2377, 4159, 12101)
# Testando o conjunto (3, 2377, 4159, 12203)
# Testando o conjunto (3, 2377, 4159, 12253)
# Testando o conjunto (3, 2377, 4159, 12269)
# Testando o conjunto (3, 2377, 4159, 12343)
# Testando o conjunto (3, 2377, 4159, 12413)
# Testando o conjunto (3, 2377, 4159, 12451)
# Testando o conjunto (3, 2377, 4159, 12601)
# Testando o conjunto (3, 2377, 4159, 12703)
# Testando o conjunto (3, 2377, 4159, 12841)
# Testando o conjunto (3, 2377, 4159, 12899)
# Testando o conjunto (3, 2377, 4159, 12979)
# Testando o conjunto (3, 2377, 4159, 13381)
# Testando o conjunto (3, 2377, 4159, 13399)
# Testando o conjunto (3, 2377, 6073, 10091)
# Testando o conjunto (3, 2377, 6073, 10111)
# Testando o conjunto (3, 2377, 6073, 10169)
# Testando o conjunto (3, 2377, 6073, 10243)
# Testando o conjunto (3, 2377, 6073, 10333)
# Testando o conjunto (3, 2377, 6073, 10357)
# Testando o conjunto (3, 2377, 6073, 10459)
# Testando o conjunto (3, 2377, 6073, 10567)
# Testando o conjunto (3, 2377, 6073, 10627)
# Testando o conjunto (3, 2377, 6073, 10771)
# Testando o conjunto (3, 2377, 6073, 10889)
# Testando o conjunto (3, 2377, 6073, 10987)
# Testando o conjunto (3, 2377, 6073, 11027)
# Testando o conjunto (3, 2377, 6073, 11197)
# Testando o conjunto (3, 2377, 6073, 11393)
# Testando o conjunto (3, 2377, 6073, 11447)
# Testando o conjunto (3, 2381, 6563, 10091)
# Testando o conjunto (3, 2381, 6563, 10111)
# Testando o conjunto (3, 2381, 6563, 10169)
# Testando o conjunto (3, 2381, 6563, 10223)
# Testando o conjunto (3, 2381, 6563, 10243)
# Testando o conjunto (3, 2381, 6563, 10333)
# Testando o conjunto (3, 2381, 6563, 10357)
# Testando o conjunto (3, 2381, 6563, 10459)
# Testando o conjunto (3, 2381, 6563, 10567)
# Testando o conjunto (3, 2381, 6563, 10627)
# Testando o conjunto (3, 2381, 6563, 10771)
# Testando o conjunto (3, 2381, 6563, 10889)
# Testando o conjunto (3, 2381, 6563, 10987)
# Testando o conjunto (3, 2381, 6563, 11027)
# Testando o conjunto (3, 2411, 4253, 10091)
# Testando o conjunto (3, 2411, 4253, 10111)
# Testando o conjunto (3, 2411, 4253, 10169)
# Testando o conjunto (3, 2411, 4253, 10223)
# Testando o conjunto (3, 2411, 4253, 10243)
# Testando o conjunto (3, 2411, 4253, 10333)
# Testando o conjunto (3, 2411, 4253, 10357)
# Testando o conjunto (3, 2411, 4253, 10459)
# Testando o conjunto (3, 2411, 4253, 10567)
# Testando o conjunto (3, 2411, 4253, 10627)
# Testando o conjunto (3, 2411, 4253, 10771)
# Testando o conjunto (3, 2411, 4253, 10889)
# Testando o conjunto (3, 2411, 4253, 10987)
# Testando o conjunto (3, 2411, 4253, 11027)
# Testando o conjunto (3, 2411, 4253, 11173)
# Testando o conjunto (3, 2411, 4253, 11177)
# Testando o conjunto (3, 2411, 4253, 11197)
# Testando o conjunto (3, 2411, 4253, 11393)
# Testando o conjunto (3, 2411, 4253, 11447)
# Testando o conjunto (3, 2411, 4253, 11551)
# Testando o conjunto (3, 2411, 4253, 11821)
# Testando o conjunto (3, 2411, 4253, 11827)
# Testando o conjunto (3, 2411, 4253, 11867)

# %%
# p1, p2, p3, p4 = (3, 7, 109, 673)
result4 = (3, 7, 109, 673)
for p5 in primes_minus_2:
    if p5 <= max(result4):
        continue
    list_primes = list(result4)
    list_primes.append(p5)
    conj = tuple(list_primes)
    good_set = True
    if p5 == 10009:
        pass
    
    for p1, p2 in product(list_primes, repeat=2):
        if p1 == p2:
            continue
        
        if ((p1, p2) in bad_pairs) or ((p2, p1) in bad_pairs):
            good_set = False
            break

        conc1 = int(str(p1)+str(p2))
        conc2 = int(str(p2)+str(p1))

        if not test_prime(conc1) or not test_prime(conc2):
            good_set = False
            bad_pairs.add((p1, p2))
            break

    if good_set:
        # conj = (p1, p2, p3, p4, p5)
        set_sum = sum(conj)
        break

if good_set:
    print(f'Resultado positivo. O conjunto {conj} tem soma {set_sum}')
else:
    print(f'Resultado negativo. Foram testados {count} conjuntos e o último foi {conj}.')
# Out:
# Resultado negativo. Foram testados 101419 conjuntos e o último foi (3, 7, 109, 673, 31583).

# %%
if good_set:
    print(f'Resultado positivo. O conjunto {conj} tem soma {set_sum}')
else:
    print(f'Resultado negativo. Foram testados {count} conjuntos e o último foi {conj}.')
